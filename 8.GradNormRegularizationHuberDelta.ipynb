# %%
import tensorflow as tf
from tensorflow import keras
import mlflow
import numpy as np
import io
import time
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

from utils import *

# %%
def custom_loss(fk_weight, huber_delta):
    def loss_fn(y_true, y_pred):
        # Huber loss for joint angles
        angle_loss = tf.keras.losses.Huber(delta=huber_delta)(y_true, y_pred)
        
        # Forward kinematics loss (using Huber loss)
        fk_true = forward_kinematics_tf(y_true)
        fk_pred = forward_kinematics_tf(y_pred)
        fk_loss = tf.keras.losses.Huber(delta=huber_delta)(fk_true, fk_pred)
        
        # Combine losses
        total_loss = angle_loss + fk_weight * fk_loss
        return total_loss
    return loss_fn

def create_model(config):
    regularizer = None
    if config['regularization'] == 'l1':
        regularizer = keras.regularizers.l1(config['reg_rate'])
    elif config['regularization'] == 'l2':
        regularizer = keras.regularizers.l2(config['reg_rate'])
    elif config['regularization'] == 'l1_l2':
        regularizer = keras.regularizers.l1_l2(l1=config['reg_rate'], l2=config['reg_rate'])

    model = keras.Sequential([
        keras.layers.Dense(128, input_shape=(3,), kernel_regularizer=regularizer),
        keras.layers.Activation('relu'),
        keras.layers.Dropout(config['dropout_rate']),
        
        keras.layers.Dense(256, kernel_regularizer=regularizer),
        keras.layers.Activation('relu'),
        keras.layers.Dropout(config['dropout_rate']),
        
        keras.layers.Dense(256, kernel_regularizer=regularizer),
        keras.layers.Activation('relu'),
        keras.layers.Dropout(config['dropout_rate']),
        
        keras.layers.Dense(128, kernel_regularizer=regularizer),
        keras.layers.Activation('relu'),
        keras.layers.Dropout(config['dropout_rate']),
        
        keras.layers.Dense(3, activation='tanh')
    ])
    
    model.compile(optimizer='adam', loss=custom_loss(config['fk_weight'], config['huber_delta']))
    return model

def run_single_experiment(config):
    (train_inputs, train_outputs), (test_inputs, test_outputs), input_mean, input_std = load_and_preprocess_data()
    
    valid_inputs, test_inputs, valid_outputs, test_outputs = train_test_split(
        test_inputs, test_outputs, test_size=0.5, random_state=42
    )
    
    mlflow.set_experiment(config['experiment_name'])
    
    with mlflow.start_run(run_name=config['model_name']):
        mlflow.log_params(config)
        
        steps_per_epoch = len(train_inputs) // config['batch_size']
        total_steps = steps_per_epoch * config['epochs']
        warmup_steps = int(0.1 * total_steps)
        
        model = create_model(config)
        
        model_summary = io.StringIO()
        model.summary(print_fn=lambda x: model_summary.write(x + '\n'))
        mlflow.log_text(model_summary.getvalue(), "model_summary.txt")
        
        early_stopping = keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True)
        lr_scheduler = CosineDecayWithWarmupCallback(
            config['initial_learning_rate'],
            warmup_steps,
            total_steps
        )
        verbose_logging = VerboseLoggingCallback()
        lr_logger = LearningRateLogger()
        
        callbacks = [lr_scheduler, verbose_logging, lr_logger, early_stopping]
        
        callback_names = [callback.__class__.__name__ for callback in callbacks]
        mlflow.log_param("callbacks", ", ".join(callback_names))
        
        start_time = time.time()
        history = model.fit(
            train_inputs, train_outputs,
            epochs=config['epochs'],
            batch_size=config['batch_size'],
            validation_data=(valid_inputs, valid_outputs),
            callbacks=callbacks
        )
        training_time = time.time() - start_time
        
        for epoch, (loss, val_loss) in enumerate(zip(history.history['loss'], history.history['val_loss'])):
            mlflow.log_metric("train_loss", loss, step=epoch)
            mlflow.log_metric("val_loss", val_loss, step=epoch)
        
        mlflow.log_metric("training_time", training_time)
        
        mlflow.tensorflow.log_model(model, "model")
        
        mlflow.log_text(verbose_logging.get_output(), "training_output.txt")
        
        errors, true_xyz, predicted_xyz = evaluate_model(model, test_inputs, test_outputs, input_mean, input_std)
        
        mlflow.log_metric("mean_error", np.mean(errors))
        mlflow.log_metric("median_error", np.median(errors))
        mlflow.log_metric("90th_percentile_error", np.percentile(errors, 90))
        mlflow.log_metric("max_error", np.max(errors))
        
        true_vs_pred_plot_path = f"./Figures/Regularization/{config['model_name']}_true_vs_predicted.png"
        plot_true_vs_predicted(true_xyz, predicted_xyz, f"{config['model_name']} Model: True vs Predicted", save_path=true_vs_pred_plot_path)
        mlflow.log_artifact(true_vs_pred_plot_path)
        
        error_dist_plot_path = f"./Figures/Regularization/{config['model_name']}_error_distribution.png"
        plot_error_distribution(errors, f"{config['model_name']} Model: Error Distribution", save_path=error_dist_plot_path)
        mlflow.log_artifact(error_dist_plot_path)
        
        print(f"\n{config['model_name']} Model:")
        print(f"Mean Error: {np.mean(errors):.4f}")
        print(f"Median Error: {np.median(errors):.4f}")
        print(f"90th Percentile Error: {np.percentile(errors, 90):.4f}")
        print(f"Max Error: {np.max(errors):.4f}")
        print(f"Training Time: {training_time:.2f} seconds")
        
        return {
            'model': model,
            'history': history,
            'errors': errors,
            'true_xyz': true_xyz,
            'predicted_xyz': predicted_xyz,
            'training_time': training_time
        }

# %%
# Create configurations
configs = []
regularization_types = [None, 'l1', 'l2', 'l1_l2']
dropout_rates = [0.0, 0.1, 0.3]
huber_deltas = [0.01, 0.02, 0.05]
learning_rates = [0.001, 0.01, 0.05]
reg_rates = [0.0001, 0.001, 0.01]  # New list for regularization rates

for reg_type in regularization_types:
    for dropout_rate in dropout_rates:
        for huber_delta in huber_deltas:
            for learning_rate in learning_rates:
                if reg_type is None:
                    config = {
                        "model_name": f"Model_Reg_None_Dropout_{dropout_rate}_HuberDelta_{huber_delta}_LR_{learning_rate}",
                        "fk_weight": 10,
                        "epochs": 50,
                        "initial_learning_rate": learning_rate,
                        "batch_size": 65536,
                        "experiment_name": "Inverse Kinematics Regularization",
                        "regularization": None,
                        "reg_rate": 0.0,
                        "dropout_rate": dropout_rate,
                        "huber_delta": huber_delta
                    }
                    configs.append(config)
                else:
                    for reg_rate in reg_rates:
                        config = {
                            "model_name": f"Model_Reg_{reg_type}_Rate_{reg_rate}_Dropout_{dropout_rate}_HuberDelta_{huber_delta}_LR_{learning_rate}",
                            "fk_weight": 10,
                            "epochs": 50,
                            "initial_learning_rate": learning_rate,
                            "batch_size": 65536,
                            "experiment_name": "Inverse Kinematics Regularization",
                            "regularization": reg_type,
                            "reg_rate": reg_rate,
                            "dropout_rate": dropout_rate,
                            "huber_delta": huber_delta
                        }
                        configs.append(config)

# Print the total number of configurations
print(f"Total number of configurations: {len(configs)}")
# Out:
# Total number of configurations: 270

# %%
# Run experiments
for config in configs:
    run_single_experiment(config)
# Out:
# WARNING:root:Malformed experiment 'mlruns'. Detailed error Yaml file '/tf/workdir/mlruns/mlruns/meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/mlflow/store/tracking/file_store.py", line 317, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#   File "/usr/local/lib/python3.8/dist-packages/mlflow/store/tracking/file_store.py", line 410, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#   File "/usr/local/lib/python3.8/dist-packages/mlflow/store/tracking/file_store.py", line 1341, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#   File "/usr/local/lib/python3.8/dist-packages/mlflow/store/tracking/file_store.py", line 1334, in _read_helper
#     result = read_yaml(root, file_name)
#   File "/usr/local/lib/python3.8/dist-packages/mlflow/utils/file_utils.py", line 309, in read_yaml
#     raise MissingConfigException(f"Yaml file '{file_path}' does not exist.")
# mlflow.exceptions.MissingConfigException: Yaml file '/tf/workdir/mlruns/mlruns/meta.yaml' does not exist.
# Epoch 1/50
# 137/138 [============================>.] - ETA: 0s - loss: 0.0435Epoch 1/50 - loss: 0.0435 - val_loss: 0.0178
# 138/138 [==============================] - 3s 12ms/step - loss: 0.0435 - val_loss: 0.0178
# Epoch 2/50
# 137/138 [============================>.] - ETA: 0s - loss: 0.0122Epoch 2/50 - loss: 0.0122 - val_loss: 0.0093
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0122 - val_loss: 0.0093
# Epoch 3/50
# 136/138 [============================>.] - ETA: 0s - loss: 0.0086Epoch 3/50 - loss: 0.0086 - val_loss: 0.0084
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0086 - val_loss: 0.0084
# Epoch 4/50
# 138/138 [==============================] - ETA: 0s - loss: 0.0075Epoch 4/50 - loss: 0.0075 - val_loss: 0.0070
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0075 - val_loss: 0.0070
# Epoch 5/50
# 138/138 [==============================] - ETA: 0s - loss: 0.0070Epoch 5/50 - loss: 0.0070 - val_loss: 0.0065
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0070 - val_loss: 0.0065
# Epoch 6/50
# 133/138 [===========================>..] - ETA: 0s - loss: 0.0063Epoch 6/50 - loss: 0.0063 - val_loss: 0.0061
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0063 - val_loss: 0.0061
# Epoch 7/50
# 135/138 [============================>.] - ETA: 0s - loss: 0.0059Epoch 7/50 - loss: 0.0059 - val_loss: 0.0057
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0059 - val_loss: 0.0057
# Epoch 8/50
# 137/138 [============================>.] - ETA: 0s - loss: 0.0055Epoch 8/50 - loss: 0.0055 - val_loss: 0.0053
# 138/138 [==============================] - 1s 11ms/step - loss: 0.0055 - val_loss: 0.0053
# Epoch 9/50
# 135/138 [============================>.] - ETA: 0s - loss: 0.0048Epoch 9/50 - loss: 0.0048 - val_loss: 0.0047
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0048 - val_loss: 0.0047
# Epoch 10/50
# 133/138 [===========================>..] - ETA: 0s - loss: 0.0038Epoch 10/50 - loss: 0.0038 - val_loss: 0.0033
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0038 - val_loss: 0.0033
# Epoch 11/50
# 133/138 [===========================>..] - ETA: 0s - loss: 0.0034Epoch 11/50 - loss: 0.0034 - val_loss: 0.0031
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0034 - val_loss: 0.0031
# Epoch 12/50
# 137/138 [============================>.] - ETA: 0s - loss: 0.0030Epoch 12/50 - loss: 0.0030 - val_loss: 0.0030
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 13/50
# 138/138 [==============================] - ETA: 0s - loss: 0.0028Epoch 13/50 - loss: 0.0028 - val_loss: 0.0028
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 14/50
# 133/138 [===========================>..] - ETA: 0s - loss: 0.0027Epoch 14/50 - loss: 0.0027 - val_loss: 0.0027
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 15/50
# 133/138 [===========================>..] - ETA: 0s - loss: 0.0026Epoch 15/50 - loss: 0.0026 - val_loss: 0.0026
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 16/50
# 134/138 [============================>.] - ETA: 0s - loss: 0.0025Epoch 16/50 - loss: 0.0025 - val_loss: 0.0025
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 17/50
# 135/138 [============================>.] - ETA: 0s - loss: 0.0024Epoch 17/50 - loss: 0.0024 - val_loss: 0.0024
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 18/50
# 135/138 [============================>.] - ETA: 0s - loss: 0.0024Epoch 18/50 - loss: 0.0024 - val_loss: 0.0023
# 138/138 [==============================] - 1s 11ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 19/50
# 137/138 [============================>.] - ETA: 0s - loss: 0.0023Epoch 19/50 - loss: 0.0023 - val_loss: 0.0023
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 20/50
# 134/138 [============================>.] - ETA: 0s - loss: 0.0023Epoch 20/50 - loss: 0.0023 - val_loss: 0.0023
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 21/50
# 134/138 [============================>.] - ETA: 0s - loss: 0.0022Epoch 21/50 - loss: 0.0022 - val_loss: 0.0022
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 22/50
# 134/138 [============================>.] - ETA: 0s - loss: 0.0021Epoch 22/50 - loss: 0.0021 - val_loss: 0.0021
# 138/138 [==============================] - 1s 11ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 23/50
# 133/138 [===========================>..] - ETA: 0s - loss: 0.0021Epoch 23/50 - loss: 0.0021 - val_loss: 0.0021
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 24/50
# 134/138 [============================>.] - ETA: 0s - loss: 0.0021Epoch 24/50 - loss: 0.0021 - val_loss: 0.0021
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 25/50
# 134/138 [============================>.] - ETA: 0s - loss: 0.0020Epoch 25/50 - loss: 0.0020 - val_loss: 0.0020
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 26/50
# 136/138 [============================>.] - ETA: 0s - loss: 0.0020Epoch 26/50 - loss: 0.0020 - val_loss: 0.0020
# 138/138 [==============================] - 1s 11ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 27/50
# 137/138 [============================>.] - ETA: 0s - loss: 0.0020Epoch 27/50 - loss: 0.0020 - val_loss: 0.0020
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 28/50
# 138/138 [==============================] - ETA: 0s - loss: 0.0020Epoch 28/50 - loss: 0.0020 - val_loss: 0.0020
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 29/50
# 134/138 [============================>.] - ETA: 0s - loss: 0.0019Epoch 29/50 - loss: 0.0019 - val_loss: 0.0019
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 30/50
# 134/138 [============================>.] - ETA: 0s - loss: 0.0019Epoch 30/50 - loss: 0.0019 - val_loss: 0.0019
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 31/50
# 133/138 [===========================>..] - ETA: 0s - loss: 0.0019Epoch 31/50 - loss: 0.0019 - val_loss: 0.0019
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 32/50
# 138/138 [==============================] - ETA: 0s - loss: 0.0019Epoch 32/50 - loss: 0.0019 - val_loss: 0.0019
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 33/50
# 137/138 [============================>.] - ETA: 0s - loss: 0.0019Epoch 33/50 - loss: 0.0019 - val_loss: 0.0019
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 34/50
# 133/138 [===========================>..] - ETA: 0s - loss: 0.0019Epoch 34/50 - loss: 0.0019 - val_loss: 0.0019
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 35/50
# 136/138 [============================>.] - ETA: 0s - loss: 0.0019Epoch 35/50 - loss: 0.0019 - val_loss: 0.0019
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 36/50
# 138/138 [==============================] - ETA: 0s - loss: 0.0019Epoch 36/50 - loss: 0.0019 - val_loss: 0.0019
# 138/138 [==============================] - 1s 11ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 37/50
# 137/138 [============================>.] - ETA: 0s - loss: 0.0019Epoch 37/50 - loss: 0.0019 - val_loss: 0.0019
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 38/50
# 136/138 [============================>.] - ETA: 0s - loss: 0.0019Epoch 38/50 - loss: 0.0019 - val_loss: 0.0019
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 39/50
# 136/138 [============================>.] - ETA: 0s - loss: 0.0019Epoch 39/50 - loss: 0.0019 - val_loss: 0.0019
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 40/50
# 137/138 [============================>.] - ETA: 0s - loss: 0.0019Epoch 40/50 - loss: 0.0019 - val_loss: 0.0019
# 138/138 [==============================] - 1s 11ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 41/50
# 133/138 [===========================>..] - ETA: 0s - loss: 0.0019Epoch 41/50 - loss: 0.0019 - val_loss: 0.0019
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 42/50
# 138/138 [==============================] - ETA: 0s - loss: 0.0019Epoch 42/50 - loss: 0.0019 - val_loss: 0.0019
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 43/50
# 137/138 [============================>.] - ETA: 0s - loss: 0.0019Epoch 43/50 - loss: 0.0019 - val_loss: 0.0019
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 44/50
# 133/138 [===========================>..] - ETA: 0s - loss: 0.0019Epoch 44/50 - loss: 0.0019 - val_loss: 0.0019
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 45/50
# 134/138 [============================>.] - ETA: 0s - loss: 0.0019Epoch 45/50 - loss: 0.0019 - val_loss: 0.0019
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 46/50
# 137/138 [============================>.] - ETA: 0s - loss: 0.0019Epoch 46/50 - loss: 0.0019 - val_loss: 0.0019
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 47/50
# 138/138 [==============================] - ETA: 0s - loss: 0.0019Epoch 47/50 - loss: 0.0019 - val_loss: 0.0019
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 48/50
# 135/138 [============================>.] - ETA: 0s - loss: 0.0019Epoch 48/50 - loss: 0.0019 - val_loss: 0.0019
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 49/50
# 133/138 [===========================>..] - ETA: 0s - loss: 0.0019Epoch 49/50 - loss: 0.0019 - val_loss: 0.0019
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 50/50
# 136/138 [============================>.] - ETA: 0s - loss: 0.0019Epoch 50/50 - loss: 0.0019 - val_loss: 0.0019
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0019
# 2024/08/20 18:54:05 WARNING mlflow.tensorflow: You are saving a TensorFlow Core model or Keras model without a signature. Inference with mlflow.pyfunc.spark_udf() will not work unless the model's pyfunc representation accepts pandas DataFrames as inference inputs.
# INFO:tensorflow:Assets written to: /tmp/tmpvatmtooy/model/data/model/assets
# INFO:tensorflow:Assets written to: /tmp/tmpvatmtooy/model/data/model/assets
# 2024/08/20 18:54:10 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /tmp/tmpvatmtooy/model, flavor: tensorflow). Fall back to return ['tensorflow==2.10.1']. Set logging level to DEBUG to see the full traceback.
# /usr/local/lib/python3.8/dist-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# 2024/08/20 18:54:10 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# 8/8 [==============================] - 0s 3ms/step
#
# Model_Reg_None_Dropout_0.0_HuberDelta_0.01_LR_0.001 Model:
# Mean Error: 0.0180
# Median Error: 0.0128
# 90th Percentile Error: 0.0327
# Max Error: 3.9670
# Training Time: 73.28 seconds
# WARNING:root:Malformed experiment 'mlruns'. Detailed error Yaml file '/tf/workdir/mlruns/mlruns/meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/mlflow/store/tracking/file_store.py", line 317, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#   File "/usr/local/lib/python3.8/dist-packages/mlflow/store/tracking/file_store.py", line 410, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#   File "/usr/local/lib/python3.8/dist-packages/mlflow/store/tracking/file_store.py", line 1341, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#   File "/usr/local/lib/python3.8/dist-packages/mlflow/store/tracking/file_store.py", line 1334, in _read_helper
#     result = read_yaml(root, file_name)
#   File "/usr/local/lib/python3.8/dist-packages/mlflow/utils/file_utils.py", line 309, in read_yaml
#     raise MissingConfigException(f"Yaml file '{file_path}' does not exist.")
# mlflow.exceptions.MissingConfigException: Yaml file '/tf/workdir/mlruns/mlruns/meta.yaml' does not exist.
# Epoch 1/50
# 135/138 [============================>.] - ETA: 0s - loss: 0.0249Epoch 1/50 - loss: 0.0246 - val_loss: 0.0096
# 138/138 [==============================] - 2s 11ms/step - loss: 0.0246 - val_loss: 0.0096
# Epoch 2/50
# 135/138 [============================>.] - ETA: 0s - loss: 0.0085Epoch 2/50 - loss: 0.0085 - val_loss: 0.0077
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0085 - val_loss: 0.0077
# Epoch 3/50
# 135/138 [============================>.] - ETA: 0s - loss: 0.0070Epoch 3/50 - loss: 0.0070 - val_loss: 0.0058
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0070 - val_loss: 0.0058
# Epoch 4/50
# 137/138 [============================>.] - ETA: 0s - loss: 0.0061Epoch 4/50 - loss: 0.0061 - val_loss: 0.0054
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0061 - val_loss: 0.0054
# Epoch 5/50
# 137/138 [============================>.] - ETA: 0s - loss: 0.0051Epoch 5/50 - loss: 0.0051 - val_loss: 0.0045
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0051 - val_loss: 0.0045
# Epoch 6/50
# 134/138 [============================>.] - ETA: 0s - loss: 0.0050Epoch 6/50 - loss: 0.0050 - val_loss: 0.0047
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0050 - val_loss: 0.0047
# Epoch 7/50
# 135/138 [============================>.] - ETA: 0s - loss: 0.0047Epoch 7/50 - loss: 0.0047 - val_loss: 0.0044
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0047 - val_loss: 0.0044
# Epoch 8/50
# 136/138 [============================>.] - ETA: 0s - loss: 0.0041Epoch 8/50 - loss: 0.0041 - val_loss: 0.0039
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0041 - val_loss: 0.0039
# Epoch 9/50
# 137/138 [============================>.] - ETA: 0s - loss: 0.0037Epoch 9/50 - loss: 0.0037 - val_loss: 0.0030
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0037 - val_loss: 0.0030
# Epoch 10/50
# 138/138 [==============================] - ETA: 0s - loss: 0.0036Epoch 10/50 - loss: 0.0036 - val_loss: 0.0033
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0036 - val_loss: 0.0033
# Epoch 11/50
# 138/138 [==============================] - ETA: 0s - loss: 0.0035Epoch 11/50 - loss: 0.0035 - val_loss: 0.0035
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0035 - val_loss: 0.0035
# Epoch 12/50
# 134/138 [============================>.] - ETA: 0s - loss: 0.0032Epoch 12/50 - loss: 0.0032 - val_loss: 0.0028
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0032 - val_loss: 0.0028
# Epoch 13/50
# 135/138 [============================>.] - ETA: 0s - loss: 0.0032Epoch 13/50 - loss: 0.0032 - val_loss: 0.0026
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0032 - val_loss: 0.0026
# Epoch 14/50
# 137/138 [============================>.] - ETA: 0s - loss: 0.0031Epoch 14/50 - loss: 0.0031 - val_loss: 0.0026
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0031 - val_loss: 0.0026
# Epoch 15/50
# 133/138 [===========================>..] - ETA: 0s - loss: 0.0029Epoch 15/50 - loss: 0.0029 - val_loss: 0.0023
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 16/50
# 135/138 [============================>.] - ETA: 0s - loss: 0.0023Epoch 16/50 - loss: 0.0023 - val_loss: 0.0022
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 17/50
# 138/138 [==============================] - ETA: 0s - loss: 0.0022Epoch 17/50 - loss: 0.0022 - val_loss: 0.0023
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0022 - val_loss: 0.0023
# Epoch 18/50
# 136/138 [============================>.] - ETA: 0s - loss: 0.0022Epoch 18/50 - loss: 0.0022 - val_loss: 0.0022
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 19/50
# 137/138 [============================>.] - ETA: 0s - loss: 0.0022Epoch 19/50 - loss: 0.0022 - val_loss: 0.0022
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 20/50
# 132/138 [===========================>..] - ETA: 0s - loss: 0.0021Epoch 20/50 - loss: 0.0021 - val_loss: 0.0021
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 21/50
# 135/138 [============================>.] - ETA: 0s - loss: 0.0021Epoch 21/50 - loss: 0.0021 - val_loss: 0.0021
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 22/50
# 135/138 [============================>.] - ETA: 0s - loss: 0.0021Epoch 22/50 - loss: 0.0021 - val_loss: 0.0021
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 23/50
# 136/138 [============================>.] - ETA: 0s - loss: 0.0021Epoch 23/50 - loss: 0.0021 - val_loss: 0.0020
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 24/50
# 135/138 [============================>.] - ETA: 0s - loss: 0.0020Epoch 24/50 - loss: 0.0020 - val_loss: 0.0020
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 25/50
# 135/138 [============================>.] - ETA: 0s - loss: 0.0020Epoch 25/50 - loss: 0.0020 - val_loss: 0.0019
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 26/50
# 133/138 [===========================>..] - ETA: 0s - loss: 0.0019Epoch 26/50 - loss: 0.0019 - val_loss: 0.0020
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 27/50
# 137/138 [============================>.] - ETA: 0s - loss: 0.0019Epoch 27/50 - loss: 0.0019 - val_loss: 0.0019
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 28/50
# 135/138 [============================>.] - ETA: 0s - loss: 0.0019Epoch 28/50 - loss: 0.0019 - val_loss: 0.0019
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 29/50
# 134/138 [============================>.] - ETA: 0s - loss: 0.0018Epoch 29/50 - loss: 0.0018 - val_loss: 0.0018
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 30/50
# 137/138 [============================>.] - ETA: 0s - loss: 0.0018Epoch 30/50 - loss: 0.0018 - val_loss: 0.0018
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 31/50
# 133/138 [===========================>..] - ETA: 0s - loss: 0.0018Epoch 31/50 - loss: 0.0018 - val_loss: 0.0018
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 32/50
# 134/138 [============================>.] - ETA: 0s - loss: 0.0018Epoch 32/50 - loss: 0.0018 - val_loss: 0.0018
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 33/50
# 135/138 [============================>.] - ETA: 0s - loss: 0.0018Epoch 33/50 - loss: 0.0018 - val_loss: 0.0017
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 34/50
# 135/138 [============================>.] - ETA: 0s - loss: 0.0018Epoch 34/50 - loss: 0.0018 - val_loss: 0.0017
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 35/50
# 134/138 [============================>.] - ETA: 0s - loss: 0.0018Epoch 35/50 - loss: 0.0018 - val_loss: 0.0018
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 36/50
# 137/138 [============================>.] - ETA: 0s - loss: 0.0018Epoch 36/50 - loss: 0.0018 - val_loss: 0.0017
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 37/50
# 134/138 [============================>.] - ETA: 0s - loss: 0.0017Epoch 37/50 - loss: 0.0017 - val_loss: 0.0018
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 38/50
# 135/138 [============================>.] - ETA: 0s - loss: 0.0017Epoch 38/50 - loss: 0.0017 - val_loss: 0.0017
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 39/50
# 136/138 [============================>.] - ETA: 0s - loss: 0.0017Epoch 39/50 - loss: 0.0017 - val_loss: 0.0017
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 40/50
# 136/138 [============================>.] - ETA: 0s - loss: 0.0017Epoch 40/50 - loss: 0.0017 - val_loss: 0.0017
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 41/50
# 138/138 [==============================] - ETA: 0s - loss: 0.0017Epoch 41/50 - loss: 0.0017 - val_loss: 0.0017
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 42/50
# 132/138 [===========================>..] - ETA: 0s - loss: 0.0017Epoch 42/50 - loss: 0.0017 - val_loss: 0.0017
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 43/50
# 134/138 [============================>.] - ETA: 0s - loss: 0.0017Epoch 43/50 - loss: 0.0017 - val_loss: 0.0017
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 44/50
# 134/138 [============================>.] - ETA: 0s - loss: 0.0017Epoch 44/50 - loss: 0.0017 - val_loss: 0.0017
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 45/50
# 133/138 [===========================>..] - ETA: 0s - loss: 0.0017Epoch 45/50 - loss: 0.0017 - val_loss: 0.0017
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 46/50
# 133/138 [===========================>..] - ETA: 0s - loss: 0.0017Epoch 46/50 - loss: 0.0017 - val_loss: 0.0017
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 47/50
# 137/138 [============================>.] - ETA: 0s - loss: 0.0017Epoch 47/50 - loss: 0.0017 - val_loss: 0.0017
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 48/50
# 135/138 [============================>.] - ETA: 0s - loss: 0.0017Epoch 48/50 - loss: 0.0017 - val_loss: 0.0017
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 49/50
# 138/138 [==============================] - ETA: 0s - loss: 0.0017Epoch 49/50 - loss: 0.0017 - val_loss: 0.0017
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 50/50
# 135/138 [============================>.] - ETA: 0s - loss: 0.0017Epoch 50/50 - loss: 0.0017 - val_loss: 0.0017
# 138/138 [==============================] - 2s 11ms/step - loss: 0.0017 - val_loss: 0.0017
# 2024/08/20 18:55:28 WARNING mlflow.tensorflow: You are saving a TensorFlow Core model or Keras model without a signature. Inference with mlflow.pyfunc.spark_udf() will not work unless the model's pyfunc representation accepts pandas DataFrames as inference inputs.
# INFO:tensorflow:Assets written to: /tmp/tmplemucvop/model/data/model/assets
# INFO:tensorflow:Assets written to: /tmp/tmplemucvop/model/data/model/assets
# 2024/08/20 18:55:32 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /tmp/tmplemucvop/model, flavor: tensorflow). Fall back to return ['tensorflow==2.10.1']. Set logging level to DEBUG to see the full traceback.
# 2024/08/20 18:55:32 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# 8/8 [==============================] - 0s 3ms/step
#
# Model_Reg_None_Dropout_0.0_HuberDelta_0.01_LR_0.01 Model:
# Mean Error: 0.0114
# Median Error: 0.0082
# 90th Percentile Error: 0.0226
# Max Error: 3.9326
# Training Time: 71.05 seconds
# WARNING:root:Malformed experiment 'mlruns'. Detailed error Yaml file '/tf/workdir/mlruns/mlruns/meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/mlflow/store/tracking/file_store.py", line 317, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#   File "/usr/local/lib/python3.8/dist-packages/mlflow/store/tracking/file_store.py", line 410, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#   File "/usr/local/lib/python3.8/dist-packages/mlflow/store/tracking/file_store.py", line 1341, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#   File "/usr/local/lib/python3.8/dist-packages/mlflow/store/tracking/file_store.py", line 1334, in _read_helper
#     result = read_yaml(root, file_name)
#   File "/usr/local/lib/python3.8/dist-packages/mlflow/utils/file_utils.py", line 309, in read_yaml
#     raise MissingConfigException(f"Yaml file '{file_path}' does not exist.")
# mlflow.exceptions.MissingConfigException: Yaml file '/tf/workdir/mlruns/mlruns/meta.yaml' does not exist.
# Epoch 1/50
# 138/138 [==============================] - ETA: 0s - loss: 0.0186Epoch 1/50 - loss: 0.0186 - val_loss: 0.0098
# 138/138 [==============================] - 2s 11ms/step - loss: 0.0186 - val_loss: 0.0098
# Epoch 2/50
# 133/138 [===========================>..] - ETA: 0s - loss: 0.0096Epoch 2/50 - loss: 0.0096 - val_loss: 0.0113
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0096 - val_loss: 0.0113
# Epoch 3/50
# 138/138 [==============================] - ETA: 0s - loss: 0.0083Epoch 3/50 - loss: 0.0083 - val_loss: 0.0069
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0083 - val_loss: 0.0069
# Epoch 4/50
# 133/138 [===========================>..] - ETA: 0s - loss: 0.0074Epoch 4/50 - loss: 0.0074 - val_loss: 0.0068
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0074 - val_loss: 0.0068
# Epoch 5/50
# 137/138 [============================>.] - ETA: 0s - loss: 0.0073Epoch 5/50 - loss: 0.0073 - val_loss: 0.0059
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0073 - val_loss: 0.0059
# Epoch 6/50
# 138/138 [==============================] - ETA: 0s - loss: 0.0067Epoch 6/50 - loss: 0.0067 - val_loss: 0.0067
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0067 - val_loss: 0.0067
# Epoch 7/50
# 134/138 [============================>.] - ETA: 0s - loss: 0.0061Epoch 7/50 - loss: 0.0061 - val_loss: 0.0054
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0061 - val_loss: 0.0054
# Epoch 8/50
# 135/138 [============================>.] - ETA: 0s - loss: 0.0060Epoch 8/50 - loss: 0.0059 - val_loss: 0.0050
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0059 - val_loss: 0.0050
# Epoch 9/50
# 138/138 [==============================] - ETA: 0s - loss: 0.0053Epoch 9/50 - loss: 0.0053 - val_loss: 0.0046
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0053 - val_loss: 0.0046
# Epoch 10/50
# 136/138 [============================>.] - ETA: 0s - loss: 0.0050Epoch 10/50 - loss: 0.0050 - val_loss: 0.0042
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0050 - val_loss: 0.0042
# Epoch 11/50
# 137/138 [============================>.] - ETA: 0s - loss: 0.0047Epoch 11/50 - loss: 0.0047 - val_loss: 0.0039
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0047 - val_loss: 0.0039
# Epoch 12/50
# 135/138 [============================>.] - ETA: 0s - loss: 0.0044Epoch 12/50 - loss: 0.0045 - val_loss: 0.0053
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0045 - val_loss: 0.0053
# Epoch 13/50
# 134/138 [============================>.] - ETA: 0s - loss: 0.0047Epoch 13/50 - loss: 0.0047 - val_loss: 0.0056
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0047 - val_loss: 0.0056
# Epoch 14/50
# 133/138 [===========================>..] - ETA: 0s - loss: 0.0046Epoch 14/50 - loss: 0.0046 - val_loss: 0.0039
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0046 - val_loss: 0.0039
# Epoch 15/50
# 136/138 [============================>.] - ETA: 0s - loss: 0.0043Epoch 15/50 - loss: 0.0043 - val_loss: 0.0045
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0043 - val_loss: 0.0045
# Epoch 16/50
# 137/138 [============================>.] - ETA: 0s - loss: 0.0042Epoch 16/50 - loss: 0.0042 - val_loss: 0.0049
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0042 - val_loss: 0.0049
# Epoch 17/50
# 136/138 [============================>.] - ETA: 0s - loss: 0.0041Epoch 17/50 - loss: 0.0041 - val_loss: 0.0037
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0041 - val_loss: 0.0037
# Epoch 18/50
# 133/138 [===========================>..] - ETA: 0s - loss: 0.0039Epoch 18/50 - loss: 0.0039 - val_loss: 0.0040
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 19/50
# 135/138 [============================>.] - ETA: 0s - loss: 0.0038Epoch 19/50 - loss: 0.0038 - val_loss: 0.0034
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0038 - val_loss: 0.0034
# Epoch 20/50
# 133/138 [===========================>..] - ETA: 0s - loss: 0.0036Epoch 20/50 - loss: 0.0036 - val_loss: 0.0043
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0036 - val_loss: 0.0043
# Epoch 21/50
# 136/138 [============================>.] - ETA: 0s - loss: 0.0037Epoch 21/50 - loss: 0.0037 - val_loss: 0.0033
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0037 - val_loss: 0.0033
# Epoch 22/50
# 138/138 [==============================] - ETA: 0s - loss: 0.0034Epoch 22/50 - loss: 0.0034 - val_loss: 0.0038
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0034 - val_loss: 0.0038
# Epoch 23/50
# 134/138 [============================>.] - ETA: 0s - loss: 0.0033Epoch 23/50 - loss: 0.0033 - val_loss: 0.0035
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0033 - val_loss: 0.0035
# Epoch 24/50
# 135/138 [============================>.] - ETA: 0s - loss: 0.0035Epoch 24/50 - loss: 0.0035 - val_loss: 0.0038
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0035 - val_loss: 0.0038
# Epoch 25/50
# 138/138 [==============================] - ETA: 0s - loss: 0.0036Epoch 25/50 - loss: 0.0036 - val_loss: 0.0037
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0036 - val_loss: 0.0037
# Epoch 26/50
# 136/138 [============================>.] - ETA: 0s - loss: 0.0035Epoch 26/50 - loss: 0.0035 - val_loss: 0.0032
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0035 - val_loss: 0.0032
# Epoch 27/50
# 138/138 [==============================] - ETA: 0s - loss: 0.0029Epoch 27/50 - loss: 0.0029 - val_loss: 0.0024
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0029 - val_loss: 0.0024
# Epoch 28/50
# 138/138 [==============================] - ETA: 0s - loss: 0.0026Epoch 28/50 - loss: 0.0026 - val_loss: 0.0023
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 29/50
# 133/138 [===========================>..] - ETA: 0s - loss: 0.0025Epoch 29/50 - loss: 0.0025 - val_loss: 0.0026
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 30/50
# 134/138 [============================>.] - ETA: 0s - loss: 0.0029Epoch 30/50 - loss: 0.0029 - val_loss: 0.0030
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 31/50
# 136/138 [============================>.] - ETA: 0s - loss: 0.0032Epoch 31/50 - loss: 0.0032 - val_loss: 0.0028
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0032 - val_loss: 0.0028
# Epoch 32/50
# 138/138 [==============================] - ETA: 0s - loss: 0.0028Epoch 32/50 - loss: 0.0028 - val_loss: 0.0025
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0028 - val_loss: 0.0025
# Epoch 33/50
# 133/138 [===========================>..] - ETA: 0s - loss: 0.0025Epoch 33/50 - loss: 0.0025 - val_loss: 0.0023
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 34/50
# 138/138 [==============================] - ETA: 0s - loss: 0.0021Epoch 34/50 - loss: 0.0021 - val_loss: 0.0019
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 35/50
# 137/138 [============================>.] - ETA: 0s - loss: 0.0019Epoch 35/50 - loss: 0.0019 - val_loss: 0.0019
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 36/50
# 136/138 [============================>.] - ETA: 0s - loss: 0.0019Epoch 36/50 - loss: 0.0019 - val_loss: 0.0019
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 37/50
# 136/138 [============================>.] - ETA: 0s - loss: 0.0019Epoch 37/50 - loss: 0.0019 - val_loss: 0.0019
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 38/50
# 133/138 [===========================>..] - ETA: 0s - loss: 0.0019Epoch 38/50 - loss: 0.0019 - val_loss: 0.0020
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 39/50
# 136/138 [============================>.] - ETA: 0s - loss: 0.0019Epoch 39/50 - loss: 0.0019 - val_loss: 0.0018
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 40/50
# 138/138 [==============================] - ETA: 0s - loss: 0.0018Epoch 40/50 - loss: 0.0018 - val_loss: 0.0019
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 41/50
# 132/138 [===========================>..] - ETA: 0s - loss: 0.0018Epoch 41/50 - loss: 0.0018 - val_loss: 0.0018
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 42/50
# 135/138 [============================>.] - ETA: 0s - loss: 0.0018Epoch 42/50 - loss: 0.0018 - val_loss: 0.0018
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 43/50
# 136/138 [============================>.] - ETA: 0s - loss: 0.0018Epoch 43/50 - loss: 0.0018 - val_loss: 0.0018
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 44/50
# 133/138 [===========================>..] - ETA: 0s - loss: 0.0018Epoch 44/50 - loss: 0.0018 - val_loss: 0.0018
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 45/50
# 133/138 [===========================>..] - ETA: 0s - loss: 0.0018Epoch 45/50 - loss: 0.0018 - val_loss: 0.0018
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 46/50
# 135/138 [============================>.] - ETA: 0s - loss: 0.0018Epoch 46/50 - loss: 0.0018 - val_loss: 0.0018
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 47/50
# 137/138 [============================>.] - ETA: 0s - loss: 0.0018Epoch 47/50 - loss: 0.0018 - val_loss: 0.0018
# 138/138 [==============================] - 1s 11ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 48/50
# 133/138 [===========================>..] - ETA: 0s - loss: 0.0018Epoch 48/50 - loss: 0.0018 - val_loss: 0.0018
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 49/50
# 134/138 [============================>.] - ETA: 0s - loss: 0.0018Epoch 49/50 - loss: 0.0018 - val_loss: 0.0018
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 50/50
# 136/138 [============================>.] - ETA: 0s - loss: 0.0018Epoch 50/50 - loss: 0.0018 - val_loss: 0.0018
# 138/138 [==============================] - 1s 11ms/step - loss: 0.0018 - val_loss: 0.0018
# 2024/08/20 18:56:52 WARNING mlflow.tensorflow: You are saving a TensorFlow Core model or Keras model without a signature. Inference with mlflow.pyfunc.spark_udf() will not work unless the model's pyfunc representation accepts pandas DataFrames as inference inputs.
# INFO:tensorflow:Assets written to: /tmp/tmpazu77140/model/data/model/assets
# INFO:tensorflow:Assets written to: /tmp/tmpazu77140/model/data/model/assets
# 2024/08/20 18:56:56 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /tmp/tmpazu77140/model, flavor: tensorflow). Fall back to return ['tensorflow==2.10.1']. Set logging level to DEBUG to see the full traceback.
# 2024/08/20 18:56:56 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# 8/8 [==============================] - 0s 3ms/step
#
# Model_Reg_None_Dropout_0.0_HuberDelta_0.01_LR_0.05 Model:
# Mean Error: 0.0155
# Median Error: 0.0129
# 90th Percentile Error: 0.0273
# Max Error: 3.6867
# Training Time: 71.95 seconds
# WARNING:root:Malformed experiment 'mlruns'. Detailed error Yaml file '/tf/workdir/mlruns/mlruns/meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/mlflow/store/tracking/file_store.py", line 317, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#   File "/usr/local/lib/python3.8/dist-packages/mlflow/store/tracking/file_store.py", line 410, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#   File "/usr/local/lib/python3.8/dist-packages/mlflow/store/tracking/file_store.py", line 1341, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#   File "/usr/local/lib/python3.8/dist-packages/mlflow/store/tracking/file_store.py", line 1334, in _read_helper
#     result = read_yaml(root, file_name)
#   File "/usr/local/lib/python3.8/dist-packages/mlflow/utils/file_utils.py", line 309, in read_yaml
#     raise MissingConfigException(f"Yaml file '{file_path}' does not exist.")
# mlflow.exceptions.MissingConfigException: Yaml file '/tf/workdir/mlruns/mlruns/meta.yaml' does not exist.
# Epoch 1/50
# 134/138 [============================>.] - ETA: 0s - loss: 0.0878Epoch 1/50 - loss: 0.0865 - val_loss: 0.0345
# 138/138 [==============================] - 2s 11ms/step - loss: 0.0865 - val_loss: 0.0345
# Epoch 2/50
# 133/138 [===========================>..] - ETA: 0s - loss: 0.0236Epoch 2/50 - loss: 0.0234 - val_loss: 0.0174
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0234 - val_loss: 0.0174
# Epoch 3/50
# 133/138 [===========================>..] - ETA: 0s - loss: 0.0161Epoch 3/50 - loss: 0.0161 - val_loss: 0.0148
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0161 - val_loss: 0.0148
# Epoch 4/50
# 134/138 [============================>.] - ETA: 0s - loss: 0.0145Epoch 4/50 - loss: 0.0145 - val_loss: 0.0139
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0145 - val_loss: 0.0139
# Epoch 5/50
# 136/138 [============================>.] - ETA: 0s - loss: 0.0135Epoch 5/50 - loss: 0.0135 - val_loss: 0.0125
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0135 - val_loss: 0.0125
# Epoch 6/50
# 136/138 [============================>.] - ETA: 0s - loss: 0.0120Epoch 6/50 - loss: 0.0120 - val_loss: 0.0117
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0120 - val_loss: 0.0117
# Epoch 7/50
# 136/138 [============================>.] - ETA: 0s - loss: 0.0113Epoch 7/50 - loss: 0.0113 - val_loss: 0.0108
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0113 - val_loss: 0.0108
# Epoch 8/50
# 136/138 [============================>.] - ETA: 0s - loss: 0.0105Epoch 8/50 - loss: 0.0105 - val_loss: 0.0096
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0105 - val_loss: 0.0096
# Epoch 9/50
# 136/138 [============================>.] - ETA: 0s - loss: 0.0089Epoch 9/50 - loss: 0.0088 - val_loss: 0.0075
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0088 - val_loss: 0.0075
# Epoch 10/50
# 138/138 [==============================] - ETA: 0s - loss: 0.0070Epoch 10/50 - loss: 0.0070 - val_loss: 0.0065
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0070 - val_loss: 0.0065
# Epoch 11/50
# 137/138 [============================>.] - ETA: 0s - loss: 0.0058Epoch 11/50 - loss: 0.0058 - val_loss: 0.0056
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0058 - val_loss: 0.0056
# Epoch 12/50
# 134/138 [============================>.] - ETA: 0s - loss: 0.0053Epoch 12/50 - loss: 0.0053 - val_loss: 0.0050
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0053 - val_loss: 0.0050
# Epoch 13/50
# 135/138 [============================>.] - ETA: 0s - loss: 0.0049Epoch 13/50 - loss: 0.0049 - val_loss: 0.0048
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0049 - val_loss: 0.0048
# Epoch 14/50
# 136/138 [============================>.] - ETA: 0s - loss: 0.0047Epoch 14/50 - loss: 0.0047 - val_loss: 0.0047
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0047 - val_loss: 0.0047
# Epoch 15/50
# 135/138 [============================>.] - ETA: 0s - loss: 0.0045Epoch 15/50 - loss: 0.0045 - val_loss: 0.0045
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0045 - val_loss: 0.0045
# Epoch 16/50
# 132/138 [===========================>..] - ETA: 0s - loss: 0.0044Epoch 16/50 - loss: 0.0044 - val_loss: 0.0042
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0044 - val_loss: 0.0042
# Epoch 17/50
# 133/138 [===========================>..] - ETA: 0s - loss: 0.0043Epoch 17/50 - loss: 0.0043 - val_loss: 0.0043
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0043 - val_loss: 0.0043
# Epoch 18/50
# 135/138 [============================>.] - ETA: 0s - loss: 0.0042Epoch 18/50 - loss: 0.0042 - val_loss: 0.0042
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0042 - val_loss: 0.0042
# Epoch 19/50
# 138/138 [==============================] - ETA: 0s - loss: 0.0041Epoch 19/50 - loss: 0.0041 - val_loss: 0.0041
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 20/50
# 134/138 [============================>.] - ETA: 0s - loss: 0.0040Epoch 20/50 - loss: 0.0040 - val_loss: 0.0040
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 21/50
# 137/138 [============================>.] - ETA: 0s - loss: 0.0040Epoch 21/50 - loss: 0.0040 - val_loss: 0.0039
# 138/138 [==============================] - 1s 11ms/step - loss: 0.0040 - val_loss: 0.0039
# Epoch 22/50
# 135/138 [============================>.] - ETA: 0s - loss: 0.0039Epoch 22/50 - loss: 0.0039 - val_loss: 0.0039
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 23/50
# 136/138 [============================>.] - ETA: 0s - loss: 0.0039Epoch 23/50 - loss: 0.0039 - val_loss: 0.0039
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 24/50
# 138/138 [==============================] - ETA: 0s - loss: 0.0038Epoch 24/50 - loss: 0.0038 - val_loss: 0.0038
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 25/50
# 137/138 [============================>.] - ETA: 0s - loss: 0.0038Epoch 25/50 - loss: 0.0038 - val_loss: 0.0037
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0038 - val_loss: 0.0037
# Epoch 26/50
# 134/138 [============================>.] - ETA: 0s - loss: 0.0037Epoch 26/50 - loss: 0.0037 - val_loss: 0.0037
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 27/50
# 136/138 [============================>.] - ETA: 0s - loss: 0.0037Epoch 27/50 - loss: 0.0037 - val_loss: 0.0037
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 28/50
# 137/138 [============================>.] - ETA: 0s - loss: 0.0037Epoch 28/50 - loss: 0.0037 - val_loss: 0.0037
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 29/50
# 136/138 [============================>.] - ETA: 0s - loss: 0.0036Epoch 29/50 - loss: 0.0036 - val_loss: 0.0036
# 138/138 [==============================] - 1s 11ms/step - loss: 0.0036 - val_loss: 0.0036
# Epoch 30/50
# 136/138 [============================>.] - ETA: 0s - loss: 0.0036Epoch 30/50 - loss: 0.0036 - val_loss: 0.0036
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0036 - val_loss: 0.0036
# Epoch 31/50
# 136/138 [============================>.] - ETA: 0s - loss: 0.0036Epoch 31/50 - loss: 0.0036 - val_loss: 0.0036
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0036 - val_loss: 0.0036
# Epoch 32/50
# 133/138 [===========================>..] - ETA: 0s - loss: 0.0036Epoch 32/50 - loss: 0.0036 - val_loss: 0.0036
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0036 - val_loss: 0.0036
# Epoch 33/50
# 133/138 [===========================>..] - ETA: 0s - loss: 0.0036Epoch 33/50 - loss: 0.0036 - val_loss: 0.0036
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0036 - val_loss: 0.0036
# Epoch 34/50
# 134/138 [============================>.] - ETA: 0s - loss: 0.0036Epoch 34/50 - loss: 0.0036 - val_loss: 0.0036
# 138/138 [==============================] - 1s 11ms/step - loss: 0.0036 - val_loss: 0.0036
# Epoch 35/50
# 137/138 [============================>.] - ETA: 0s - loss: 0.0036Epoch 35/50 - loss: 0.0036 - val_loss: 0.0036
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0036 - val_loss: 0.0036
# Epoch 36/50
# 134/138 [============================>.] - ETA: 0s - loss: 0.0036Epoch 36/50 - loss: 0.0036 - val_loss: 0.0036
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0036 - val_loss: 0.0036
# Epoch 37/50
# 133/138 [===========================>..] - ETA: 0s - loss: 0.0035Epoch 37/50 - loss: 0.0035 - val_loss: 0.0035
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0035 - val_loss: 0.0035
# Epoch 38/50
# 136/138 [============================>.] - ETA: 0s - loss: 0.0035Epoch 38/50 - loss: 0.0035 - val_loss: 0.0035
# 138/138 [==============================] - 1s 10ms/step - loss: 0.0035 - val_loss: 0.0035
# Epoch 39/50
# ...
# Epoch 6/50
# 137/138 [============================>.] - ETA: 0s - loss: 0.3795Epoch 6/50 - loss: 0.3795 - val_loss: 0.3462
# 138/138 [==============================] - 2s 14ms/step - loss: 0.3795 - val_loss: 0.3462
# Epoch 7/50
# 135/138 [============================>.] - ETA: 0s - loss: 0.3768Epoch 7/50 - loss: 0.3768 - val_loss: 0.3420
# 138/138 [==============================] - 2s 14ms/step - loss: 0.3768 - val_loss: 0.3420
# 2024/08/20 22:50:20 WARNING mlflow.tensorflow: You are saving a TensorFlow Core model or Keras model without a signature. Inference with mlflow.pyfunc.spark_udf() will not work unless the model's pyfunc representation accepts pandas DataFrames as inference inputs.
# INFO:tensorflow:Assets written to: /tmp/tmpbosdckm1/model/data/model/assets
# INFO:tensorflow:Assets written to: /tmp/tmpbosdckm1/model/data/model/assets
# 2024/08/20 22:50:26 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /tmp/tmpbosdckm1/model, flavor: tensorflow). Fall back to return ['tensorflow==2.10.1']. Set logging level to DEBUG to see the full traceback.
# 2024/08/20 22:50:26 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# 8/8 [==============================] - 0s 3ms/step
#
# Model_Reg_l1_l2_Rate_0.001_Dropout_0.3_HuberDelta_0.05_LR_0.01 Model:
# Mean Error: 1.1766
# Median Error: 0.9488
# 90th Percentile Error: 2.4228
# Max Error: 4.1851
# Training Time: 15.05 seconds
# WARNING:root:Malformed experiment 'mlruns'. Detailed error Yaml file '/tf/workdir/mlruns/mlruns/meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/mlflow/store/tracking/file_store.py", line 317, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#   File "/usr/local/lib/python3.8/dist-packages/mlflow/store/tracking/file_store.py", line 410, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#   File "/usr/local/lib/python3.8/dist-packages/mlflow/store/tracking/file_store.py", line 1341, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#   File "/usr/local/lib/python3.8/dist-packages/mlflow/store/tracking/file_store.py", line 1334, in _read_helper
#     result = read_yaml(root, file_name)
#   File "/usr/local/lib/python3.8/dist-packages/mlflow/utils/file_utils.py", line 309, in read_yaml
#     raise MissingConfigException(f"Yaml file '{file_path}' does not exist.")
# mlflow.exceptions.MissingConfigException: Yaml file '/tf/workdir/mlruns/mlruns/meta.yaml' does not exist.
# Epoch 1/50
# 137/138 [============================>.] - ETA: 0s - loss: 42.4953Epoch 1/50 - loss: 42.3971 - val_loss: 1.4751
# 138/138 [==============================] - 3s 16ms/step - loss: 42.3971 - val_loss: 1.4751
# Epoch 2/50
# 137/138 [============================>.] - ETA: 0s - loss: 0.8667Epoch 2/50 - loss: 0.8669 - val_loss: 0.9211
# 138/138 [==============================] - 2s 14ms/step - loss: 0.8669 - val_loss: 0.9211
# Epoch 3/50
# 137/138 [============================>.] - ETA: 0s - loss: 1.0667Epoch 3/50 - loss: 1.0671 - val_loss: 1.2179
# 138/138 [==============================] - 2s 14ms/step - loss: 1.0671 - val_loss: 1.2179
# Epoch 4/50
# 137/138 [============================>.] - ETA: 0s - loss: 1.3750Epoch 4/50 - loss: 1.3753 - val_loss: 1.5348
# 138/138 [==============================] - 2s 14ms/step - loss: 1.3753 - val_loss: 1.5348
# Epoch 5/50
# 137/138 [============================>.] - ETA: 0s - loss: 1.6836Epoch 5/50 - loss: 1.6840 - val_loss: 1.8225
# 138/138 [==============================] - 2s 14ms/step - loss: 1.6840 - val_loss: 1.8225
# Epoch 6/50
# 137/138 [============================>.] - ETA: 0s - loss: 1.8290Epoch 6/50 - loss: 1.8290 - val_loss: 1.8249
# 138/138 [==============================] - 2s 14ms/step - loss: 1.8290 - val_loss: 1.8249
# Epoch 7/50
# 137/138 [============================>.] - ETA: 0s - loss: 1.8275Epoch 7/50 - loss: 1.8275 - val_loss: 1.8256
# 138/138 [==============================] - 2s 14ms/step - loss: 1.8275 - val_loss: 1.8256
# 2024/08/20 22:50:48 WARNING mlflow.tensorflow: You are saving a TensorFlow Core model or Keras model without a signature. Inference with mlflow.pyfunc.spark_udf() will not work unless the model's pyfunc representation accepts pandas DataFrames as inference inputs.
# INFO:tensorflow:Assets written to: /tmp/tmpamwpgckb/model/data/model/assets
# INFO:tensorflow:Assets written to: /tmp/tmpamwpgckb/model/data/model/assets
# 2024/08/20 22:50:54 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /tmp/tmpamwpgckb/model, flavor: tensorflow). Fall back to return ['tensorflow==2.10.1']. Set logging level to DEBUG to see the full traceback.
# 2024/08/20 22:50:54 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# 8/8 [==============================] - 0s 3ms/step
#
# Model_Reg_l1_l2_Rate_0.01_Dropout_0.3_HuberDelta_0.05_LR_0.01 Model:
# Mean Error: 1.7624
# Median Error: 1.6708
# 90th Percentile Error: 3.1389
# Max Error: 3.6638
# Training Time: 15.49 seconds
# WARNING:root:Malformed experiment 'mlruns'. Detailed error Yaml file '/tf/workdir/mlruns/mlruns/meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/mlflow/store/tracking/file_store.py", line 317, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#   File "/usr/local/lib/python3.8/dist-packages/mlflow/store/tracking/file_store.py", line 410, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#   File "/usr/local/lib/python3.8/dist-packages/mlflow/store/tracking/file_store.py", line 1341, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#   File "/usr/local/lib/python3.8/dist-packages/mlflow/store/tracking/file_store.py", line 1334, in _read_helper
#     result = read_yaml(root, file_name)
#   File "/usr/local/lib/python3.8/dist-packages/mlflow/utils/file_utils.py", line 309, in read_yaml
#     raise MissingConfigException(f"Yaml file '{file_path}' does not exist.")
# mlflow.exceptions.MissingConfigException: Yaml file '/tf/workdir/mlruns/mlruns/meta.yaml' does not exist.
# Epoch 1/50
# 137/138 [============================>.] - ETA: 0s - loss: 0.4446Epoch 1/50 - loss: 0.4439 - val_loss: 0.1248
# 138/138 [==============================] - 3s 16ms/step - loss: 0.4439 - val_loss: 0.1248
# Epoch 2/50
# 137/138 [============================>.] - ETA: 0s - loss: 0.1481Epoch 2/50 - loss: 0.1481 - val_loss: 0.1129
# 138/138 [==============================] - 2s 14ms/step - loss: 0.1481 - val_loss: 0.1129
# Epoch 3/50
# 137/138 [============================>.] - ETA: 0s - loss: 0.1615Epoch 3/50 - loss: 0.1615 - val_loss: 0.1540
# 138/138 [==============================] - 2s 14ms/step - loss: 0.1615 - val_loss: 0.1540
# Epoch 4/50
# 137/138 [============================>.] - ETA: 0s - loss: 0.1849Epoch 4/50 - loss: 0.1849 - val_loss: 0.1496
# 138/138 [==============================] - 2s 14ms/step - loss: 0.1849 - val_loss: 0.1496
# Epoch 5/50
# 138/138 [==============================] - ETA: 0s - loss: 0.2020Epoch 5/50 - loss: 0.2020 - val_loss: 0.1842
# 138/138 [==============================] - 2s 14ms/step - loss: 0.2020 - val_loss: 0.1842
# Epoch 6/50
# 137/138 [============================>.] - ETA: 0s - loss: 0.2085Epoch 6/50 - loss: 0.2085 - val_loss: 0.1704
# 138/138 [==============================] - 2s 14ms/step - loss: 0.2085 - val_loss: 0.1704
# Epoch 7/50
# 135/138 [============================>.] - ETA: 0s - loss: 0.2033Epoch 7/50 - loss: 0.2034 - val_loss: 0.1803
# 138/138 [==============================] - 2s 14ms/step - loss: 0.2034 - val_loss: 0.1803
# 2024/08/20 22:51:16 WARNING mlflow.tensorflow: You are saving a TensorFlow Core model or Keras model without a signature. Inference with mlflow.pyfunc.spark_udf() will not work unless the model's pyfunc representation accepts pandas DataFrames as inference inputs.
# INFO:tensorflow:Assets written to: /tmp/tmpeke38ifp/model/data/model/assets
# INFO:tensorflow:Assets written to: /tmp/tmpeke38ifp/model/data/model/assets
# 2024/08/20 22:51:21 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /tmp/tmpeke38ifp/model, flavor: tensorflow). Fall back to return ['tensorflow==2.10.1']. Set logging level to DEBUG to see the full traceback.
# 2024/08/20 22:51:21 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# 8/8 [==============================] - 0s 3ms/step
#
# Model_Reg_l1_l2_Rate_0.0001_Dropout_0.3_HuberDelta_0.05_LR_0.05 Model:
# Mean Error: 0.3661
# Median Error: 0.3265
# 90th Percentile Error: 0.6115
# Max Error: 4.3414
# Training Time: 15.26 seconds
# WARNING:root:Malformed experiment 'mlruns'. Detailed error Yaml file '/tf/workdir/mlruns/mlruns/meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/mlflow/store/tracking/file_store.py", line 317, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#   File "/usr/local/lib/python3.8/dist-packages/mlflow/store/tracking/file_store.py", line 410, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#   File "/usr/local/lib/python3.8/dist-packages/mlflow/store/tracking/file_store.py", line 1341, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#   File "/usr/local/lib/python3.8/dist-packages/mlflow/store/tracking/file_store.py", line 1334, in _read_helper
#     result = read_yaml(root, file_name)
#   File "/usr/local/lib/python3.8/dist-packages/mlflow/utils/file_utils.py", line 309, in read_yaml
#     raise MissingConfigException(f"Yaml file '{file_path}' does not exist.")
# mlflow.exceptions.MissingConfigException: Yaml file '/tf/workdir/mlruns/mlruns/meta.yaml' does not exist.
# Epoch 1/50
# 136/138 [============================>.] - ETA: 0s - loss: 2.3761Epoch 1/50 - loss: 2.3569 - val_loss: 0.3624
# 138/138 [==============================] - 3s 15ms/step - loss: 2.3569 - val_loss: 0.3624
# Epoch 2/50
# 137/138 [============================>.] - ETA: 0s - loss: 0.4633Epoch 2/50 - loss: 0.4635 - val_loss: 0.5194
# 138/138 [==============================] - 2s 14ms/step - loss: 0.4635 - val_loss: 0.5194
# Epoch 3/50
# 137/138 [============================>.] - ETA: 0s - loss: 0.6129Epoch 3/50 - loss: 0.6130 - val_loss: 0.6577
# 138/138 [==============================] - 2s 14ms/step - loss: 0.6130 - val_loss: 0.6577
# Epoch 4/50
# 138/138 [==============================] - ETA: 0s - loss: 0.7698Epoch 4/50 - loss: 0.7698 - val_loss: 0.8154
# 138/138 [==============================] - 2s 14ms/step - loss: 0.7698 - val_loss: 0.8154
# Epoch 5/50
# 134/138 [============================>.] - ETA: 0s - loss: 0.9253Epoch 5/50 - loss: 0.9273 - val_loss: 0.9900
# 138/138 [==============================] - 2s 14ms/step - loss: 0.9273 - val_loss: 0.9900
# Epoch 6/50
# 137/138 [============================>.] - ETA: 0s - loss: 0.9988Epoch 6/50 - loss: 0.9988 - val_loss: 0.9750
# 138/138 [==============================] - 2s 14ms/step - loss: 0.9988 - val_loss: 0.9750
# 2024/08/20 22:51:42 WARNING mlflow.tensorflow: You are saving a TensorFlow Core model or Keras model without a signature. Inference with mlflow.pyfunc.spark_udf() will not work unless the model's pyfunc representation accepts pandas DataFrames as inference inputs.
# INFO:tensorflow:Assets written to: /tmp/tmp9njlovx6/model/data/model/assets
# INFO:tensorflow:Assets written to: /tmp/tmp9njlovx6/model/data/model/assets
# 2024/08/20 22:51:47 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /tmp/tmp9njlovx6/model, flavor: tensorflow). Fall back to return ['tensorflow==2.10.1']. Set logging level to DEBUG to see the full traceback.
# 2024/08/20 22:51:47 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# 8/8 [==============================] - 0s 3ms/step
#
# Model_Reg_l1_l2_Rate_0.001_Dropout_0.3_HuberDelta_0.05_LR_0.05 Model:
# Mean Error: 1.2009
# Median Error: 0.9644
# 90th Percentile Error: 2.4294
# Max Error: 4.1898
# Training Time: 13.25 seconds
# WARNING:root:Malformed experiment 'mlruns'. Detailed error Yaml file '/tf/workdir/mlruns/mlruns/meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/mlflow/store/tracking/file_store.py", line 317, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#   File "/usr/local/lib/python3.8/dist-packages/mlflow/store/tracking/file_store.py", line 410, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#   File "/usr/local/lib/python3.8/dist-packages/mlflow/store/tracking/file_store.py", line 1341, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#   File "/usr/local/lib/python3.8/dist-packages/mlflow/store/tracking/file_store.py", line 1334, in _read_helper
#     result = read_yaml(root, file_name)
#   File "/usr/local/lib/python3.8/dist-packages/mlflow/utils/file_utils.py", line 309, in read_yaml
#     raise MissingConfigException(f"Yaml file '{file_path}' does not exist.")
# mlflow.exceptions.MissingConfigException: Yaml file '/tf/workdir/mlruns/mlruns/meta.yaml' does not exist.
# Epoch 1/50
# 137/138 [============================>.] - ETA: 0s - loss: 20.9300Epoch 1/50 - loss: 20.8841 - val_loss: 1.7941
# 138/138 [==============================] - 3s 15ms/step - loss: 20.8841 - val_loss: 1.7941
# Epoch 2/50
# 137/138 [============================>.] - ETA: 0s - loss: 2.5148Epoch 2/50 - loss: 2.5166 - val_loss: 3.3107
# 138/138 [==============================] - 2s 14ms/step - loss: 2.5166 - val_loss: 3.3107
# Epoch 3/50
# 137/138 [============================>.] - ETA: 0s - loss: 4.0424Epoch 3/50 - loss: 4.0441 - val_loss: 4.7973
# 138/138 [==============================] - 2s 14ms/step - loss: 4.0441 - val_loss: 4.7973
# Epoch 4/50
# 134/138 [============================>.] - ETA: 0s - loss: 5.5497Epoch 4/50 - loss: 5.5673 - val_loss: 6.3036
# 138/138 [==============================] - 2s 14ms/step - loss: 5.5673 - val_loss: 6.3036
# Epoch 5/50
# 137/138 [============================>.] - ETA: 0s - loss: 7.0977Epoch 5/50 - loss: 7.0995 - val_loss: 7.8544
# 138/138 [==============================] - 2s 14ms/step - loss: 7.0995 - val_loss: 7.8544
# Epoch 6/50
# 137/138 [============================>.] - ETA: 0s - loss: 7.8299Epoch 6/50 - loss: 7.8297 - val_loss: 7.6800
# 138/138 [==============================] - 2s 14ms/step - loss: 7.8297 - val_loss: 7.6800
# 2024/08/20 22:52:08 WARNING mlflow.tensorflow: You are saving a TensorFlow Core model or Keras model without a signature. Inference with mlflow.pyfunc.spark_udf() will not work unless the model's pyfunc representation accepts pandas DataFrames as inference inputs.
# INFO:tensorflow:Assets written to: /tmp/tmp84xt_ypf/model/data/model/assets
# INFO:tensorflow:Assets written to: /tmp/tmp84xt_ypf/model/data/model/assets
# 2024/08/20 22:52:13 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /tmp/tmp84xt_ypf/model, flavor: tensorflow). Fall back to return ['tensorflow==2.10.1']. Set logging level to DEBUG to see the full traceback.
# 2024/08/20 22:52:13 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# 8/8 [==============================] - 0s 3ms/step
#
# Model_Reg_l1_l2_Rate_0.01_Dropout_0.3_HuberDelta_0.05_LR_0.05 Model:
# Mean Error: 1.7627
# Median Error: 1.6701
# 90th Percentile Error: 3.1329
# Max Error: 3.6632
# Training Time: 13.10 seconds
